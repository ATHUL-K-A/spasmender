# %%
import sys
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000) # Widen the display area
pd.set_option('display.max_colwidth', None) # Ensure full content in columns

# %%
df_L1=pd.read_csv("data/Andre/L50.csv")
df_L2=pd.read_csv("data/Avandika/L50.csv")
df_L3=pd.read_csv("data/Athul/L50.csv")
df_L4=pd.read_csv("data/Thomas/L50.csv")

# %%
df_L2.head()
# Out:
#    Time_s  Raw_EMG  Envelope_EMG
# 0  0.0004     35.0         294.0
# 1  0.0005    -60.0         292.0
# 2  0.0007     20.0         288.0
# 3  0.0008    109.0         286.0
# 4  0.0010    -65.0         282.0

# %%
final_L=pd.concat([df_L1, df_L2, df_L3, df_L4], ignore_index=True)
final_L.to_csv("data/combined_L50.csv", index=False)

# %%
df_R1=pd.read_csv("data/Andre/R50.csv")
df_R2=pd.read_csv("data/Avandika/R50.csv")
df_R3=pd.read_csv("data/Athul/R50.csv")
df_R4=pd.read_csv("data/Thomas/R50.csv")

# %%
final_R=pd.concat([df_R1, df_R2, df_R3, df_R4], ignore_index=True)
final_R.to_csv("data/combined_R50.csv", index=False)

# %%
df_BL1=pd.read_csv("data/Andre/BL50.csv")
#df_BL2=pd.read_csv("data/Avandika/BL50.csv")
df_BL3=pd.read_csv("data/Athul/BL50.csv")
df_BL4=pd.read_csv("data/Thomas/BL50.csv")

# %%
final_BL=pd.concat([df_BL1, df_BL3, df_BL4], ignore_index=True)
final_BL.to_csv("data/combined_BL50.csv", index=False)

# %%
df_BR1=pd.read_csv("data/Andre/BR50.csv")
#df_BR2=pd.read_csv("data/Avandika/BR50.csv")
df_BR3=pd.read_csv("data/Athul/BR50.csv")
df_BR4=pd.read_csv("data/Thomas/BR50.csv")

# %%
final_BR=pd.concat([df_BR1, df_BR3, df_BR4], ignore_index=True)
final_BR.to_csv("data/combined_BR50.csv", index=False)
